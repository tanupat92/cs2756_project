# %% [markdown]
# <a href="https://colab.research.google.com/github/tanupat92/cs2756_project/blob/main/data_mining_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import sklearn as sk
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/Datamining/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Datamining/test.csv')

# %%
one_hot = pd.get_dummies(train['MSSubClass'])
train = train.drop('MSSubClass', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['MSSubClass'])
test = test.drop('MSSubClass', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['MSZoning'])
train = train.drop('MSZoning', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['MSZoning'])
test = test.drop('MSZoning', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Street'])
train = train.drop('Street', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Street'])
test = test.drop('Street', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Alley'])
one_hot.rename(columns = {'Grvl':'GrvlAlley', 'Pave':'PaveAlley', 'NA':'NAAlley'}, inplace = True)
train = train.drop('Alley', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Alley'])
one_hot.rename(columns = {'Grvl':'GrvlAlley', 'Pave':'PaveAlley', 'NA':'NAAlley'}, inplace = True)
test = test.drop('Alley', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['LotShape'])
train = train.drop('LotShape', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['LotShape'])
test = test.drop('LotShape', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['LandContour'])
train = train.drop('LandContour', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['LandContour'])
test = test.drop('LandContour', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Utilities'])
train = train.drop('Utilities', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Utilities'])
test = test.drop('Utilities', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['LotConfig'])
train = train.drop('LotConfig', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['LotConfig'])
test = test.drop('LotConfig', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['LandSlope'])
train = train.drop('LandSlope', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['LandSlope'])
test = test.drop('LandSlope', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Neighborhood'])
train = train.drop('Neighborhood', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Neighborhood'])
test = test.drop('Neighborhood', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Condition1'])
train = train.drop('Condition1', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Condition1'])
test = test.drop('Condition1', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Condition2'])
one_hot.rename(columns = {'Artery':'ArteryCond2', 'Feedr':'FeedrCond2', 'Norm':'NormCond2', 'RRNn':'RRNnCond2', 'RRAn':'RRAnCond2', 'PosN':'PosNCond2', 'PosA':'PosACond2', 'RRNe':'RRNeCond2', 'RRAe':'RRAeCond2'}, inplace = True)
train = train.drop('Condition2', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Condition2'])
one_hot.rename(columns = {'Artery':'ArteryCond2', 'Feedr':'FeedrCond2', 'Norm':'NormCond2', 'RRNn':'RRNnCond2', 'RRAn':'RRAnCond2', 'PosN':'PosNCond2', 'PosA':'PosACond2', 'RRNe':'RRNeCond2', 'RRAe':'RRAeCond2'}, inplace = True)
test = test.drop('Condition2', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BldgType'])
train = train.drop('BldgType', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BldgType'])
test = test.drop('BldgType', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['RoofStyle'])
train = train.drop('RoofStyle', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['RoofStyle'])
test = test.drop('RoofStyle', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['RoofMatl'])
train = train.drop('RoofMatl', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['RoofMatl'])
test = test.drop('RoofMatl', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Exterior1st'])
train = train.drop('Exterior1st', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Exterior1st'])
test = test.drop('Exterior1st', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Exterior2nd'])
one_hot.rename(columns = {'AsbShng':'AsbShngExter2', 'AsphShn':'AsphShnExter2', 'BrkComm':'BrkCommExter2', 'BrkFace':'BrkFaceExter2', 'CBlock':'CBlockExter2', 'CemntBd':'CemntBdExter2', 'HdBoard':'HdBoardExter2', 'ImStucc':'ImStuccExter2', 'MetalSd':'MetalSdExter2', 'Other':'OtherExter2', 'Plywood':'PlywoodExter2', 'PreCast':'PreCastExter2', 'Stone':'StoneExter2', 'Stucco':'StuccoExter2', 'VinylSd':'VinylSdExter2', 'Wd Sdng':'Wd SdngExter2', 'WdShing':'WdShingExter2'}, inplace = True)
train = train.drop('Exterior2nd', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Exterior2nd'])
one_hot.rename(columns = {'AsbShng':'AsbShngExter2', 'AsphShn':'AsphShnExter2', 'BrkComm':'BrkCommExter2', 'BrkFace':'BrkFaceExter2', 'CBlock':'CBlockExter2', 'CemntBd':'CemntBdExter2', 'HdBoard':'HdBoardExter2', 'ImStucc':'ImStuccExter2', 'MetalSd':'MetalSdExter2', 'Other':'OtherExter2', 'Plywood':'PlywoodExter2', 'PreCast':'PreCastExter2', 'Stone':'StoneExter2', 'Stucco':'StuccoExter2', 'VinylSd':'VinylSdExter2', 'Wd Sdng':'Wd SdngExter2', 'WdShing':'WdShingExter2'}, inplace = True)
test = test.drop('Exterior2nd', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['MasVnrType'])
one_hot.rename(columns = {'BrkCmn':'BrkCmnMVT', 'BrkFace':'BrkFaceMVT', 'CBlock':'CBlockMVT', 'None':'NoneMVT', 'Stone':'StoneMVT'}, inplace = True)
train = train.drop('MasVnrType', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['MasVnrType'])
one_hot.rename(columns = {'BrkCmn':'BrkCmnMVT', 'BrkFace':'BrkFaceMVT', 'CBlock':'CBlockMVT', 'None':'NoneMVT', 'Stone':'StoneMVT'}, inplace = True)
test = test.drop('MasVnrType', axis = 1)
test = test.join(one_hot)

scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1}
train['ExterQual'] = train['ExterQual'].replace(scale_mapper)
test['ExterQual'] = test['ExterQual'].replace(scale_mapper)

scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1}
train['ExterCond'] = train['ExterCond'].replace(scale_mapper)
test['ExterCond'] = test['ExterCond'].replace(scale_mapper)

one_hot = pd.get_dummies(train['Foundation'])
one_hot.rename(columns = {'BrkTil':'BrkTilFound', 'CBlock':'CBlockFound', 'PConc':'PConcFound', 'Slab':'SlabFound', 'Stone':'StoneFound', 'Wood':'WoodFound'}, inplace = True)
train = train.drop('Foundation', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Foundation'])
one_hot.rename(columns = {'BrkTil':'BrkTilFound', 'CBlock':'CBlockFound', 'PConc':'PConcFound', 'Slab':'SlabFound', 'Stone':'StoneFound', 'Wood':'WoodFound'}, inplace = True)
test = test.drop('Foundation', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BsmtQual'])
one_hot.rename(columns = {'Ex':'ExBsmtQual', 'Gd':'GdBsmtQual', 'TA':'TABsmtQual', 'Fa':'FaBsmtQual', 'Po':'PoBsmtQual', 'NA':'NABsmtQual'}, inplace = True)
train = train.drop('BsmtQual', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BsmtQual'])
one_hot.rename(columns = {'Ex':'ExBsmtQual', 'Gd':'GdBsmtQual', 'TA':'TABsmtQual', 'Fa':'FaBsmtQual', 'Po':'PoBsmtQual', 'NA':'NABsmtQual'}, inplace = True)
test = test.drop('BsmtQual', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BsmtCond'])
one_hot.rename(columns = {'Ex':'ExBsmtCond', 'Gd':'GdBsmtCond', 'TA':'TABsmtCond', 'Fa':'FaBsmtCond', 'Po':'PoBsmtCond', 'NA':'NABsmtCond'}, inplace = True)
train = train.drop('BsmtCond', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BsmtCond'])
one_hot.rename(columns = {'Ex':'ExBsmtCond', 'Gd':'GdBsmtCond', 'TA':'TABsmtCond', 'Fa':'FaBsmtCond', 'Po':'PoBsmtCond', 'NA':'NABsmtCond'}, inplace = True)
test = test.drop('BsmtCond', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BsmtExposure'])
one_hot.rename(columns = {'Ex':'ExBsmtExposure', 'Gd':'GdBsmtExposure', 'TA':'TABsmtExposure', 'Fa':'FaBsmtExposure', 'Po':'PoBsmtExposure', 'NA':'NABsmtExposure'}, inplace = True)
train = train.drop('BsmtExposure', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BsmtExposure'])
one_hot.rename(columns = {'Ex':'ExBsmtExposure', 'Gd':'GdBsmtExposure', 'TA':'TABsmtExposure', 'Fa':'FaBsmtExposure', 'Po':'PoBsmtExposure', 'NA':'NABsmtExposure'}, inplace = True)
test = test.drop('BsmtExposure', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BsmtFinType1'])
one_hot.rename(columns = {'GLQ':'GLQBsmtFin1', 'ALQ':'ALQBsmtFin1', 'BLQ':'BLQBsmtFin1', 'Rec':'RecBsmtFin1', 'LwQ':'LwQBsmtFin1', 'Unf':'UnfBsmtFin1', 'NA':'NABsmtFin1'}, inplace = True)
train = train.drop('BsmtFinType1', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BsmtFinType1'])
one_hot.rename(columns = {'GLQ':'GLQBsmtFin1', 'ALQ':'ALQBsmtFin1', 'BLQ':'BLQBsmtFin1', 'Rec':'RecBsmtFin1', 'LwQ':'LwQBsmtFin1', 'Unf':'UnfBsmtFin1', 'NA':'NABsmtFin1'}, inplace = True)
test = test.drop('BsmtFinType1', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['BsmtFinType2'])
one_hot.rename(columns = {'GLQ':'GLQBsmtFin2', 'ALQ':'ALQBsmtFin2', 'BLQ':'BLQBsmtFin2', 'Rec':'RecBsmtFin2', 'LwQ':'LwQBsmtFin2', 'Unf':'UnfBsmtFin2', 'NA':'NABsmtFin2'}, inplace = True)
train = train.drop('BsmtFinType2', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['BsmtFinType2'])
one_hot.rename(columns = {'GLQ':'GLQBsmtFin2', 'ALQ':'ALQBsmtFin2', 'BLQ':'BLQBsmtFin2', 'Rec':'RecBsmtFin2', 'LwQ':'LwQBsmtFin2', 'Unf':'UnfBsmtFin2', 'NA':'NABsmtFin2'}, inplace = True)
test = test.drop('BsmtFinType2', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Heating'])
train = train.drop('Heating', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Heating'])
test = test.drop('Heating', axis = 1)
test = test.join(one_hot)

scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1}
train['HeatingQC'] = train['HeatingQC'].replace(scale_mapper)
test['HeatingQC'] = test['HeatingQC'].replace(scale_mapper)

one_hot = pd.get_dummies(train['CentralAir'])
train = train.drop('CentralAir', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['CentralAir'])
test = test.drop('CentralAir', axis = 1)
test = test.join(one_hot)

one_hot = pd.get_dummies(train['Electrical'])
train = train.drop('Electrical', axis = 1)
train = train.join(one_hot)
one_hot = pd.get_dummies(test['Electrical'])
test = test.drop('Electrical', axis = 1)
test = test.join(one_hot)

scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1}
train['KitchenQual'] = train['KitchenQual'].replace(scale_mapper)
test['KitchenQual'] = test['KitchenQual'].replace(scale_mapper)

one_hot = pd.get_dummies(train['Functional'])
train = train.drop('Functional', axis = 1)
train = train.join(one_hot, rsuffix = 'Functional')
one_hot = pd.get_dummies(test['Functional'])
test = test.drop('Functional', axis = 1)
test = test.join(one_hot, rsuffix = 'Functional')

one_hot = pd.get_dummies(train['FireplaceQu'])
train = train.drop('FireplaceQu', axis = 1)
train = train.join(one_hot, rsuffix = 'FireplaceQu')
one_hot = pd.get_dummies(test['FireplaceQu'])
test = test.drop('FireplaceQu', axis = 1)
test = test.join(one_hot, rsuffix = 'FireplaceQu')

one_hot = pd.get_dummies(train['GarageType'])
train = train.drop('GarageType', axis = 1)
train = train.join(one_hot, rsuffix = 'GarageType')
one_hot = pd.get_dummies(test['GarageType'])
test = test.drop('GarageType', axis = 1)
test = test.join(one_hot, rsuffix = 'GarageType')

one_hot = pd.get_dummies(train['GarageFinish'])
train = train.drop('GarageFinish', axis = 1)
train = train.join(one_hot, rsuffix = 'GarageFinish')
one_hot = pd.get_dummies(test['GarageFinish'])
test = test.drop('GarageFinish', axis = 1)
test = test.join(one_hot, rsuffix = 'GarageFinish')

one_hot = pd.get_dummies(train['GarageCond'])
train = train.drop('GarageCond', axis = 1)
train = train.join(one_hot, rsuffix = 'GarageCond')
one_hot = pd.get_dummies(test['GarageCond'])
test = test.drop('GarageCond', axis = 1)
test = test.join(one_hot, rsuffix = 'GarageCond')

one_hot = pd.get_dummies(train['PavedDrive'])
train = train.drop('PavedDrive', axis = 1)
train = train.join(one_hot, rsuffix = 'PavedDrive')
one_hot = pd.get_dummies(test['PavedDrive'])
test = test.drop('PavedDrive', axis = 1)
test = test.join(one_hot, rsuffix = 'PavedDrive')

one_hot = pd.get_dummies(train['PoolQC'])
train = train.drop('PoolQC', axis = 1)
train = train.join(one_hot, rsuffix = 'PoolQC')
one_hot = pd.get_dummies(test['PoolQC'])
test = test.drop('PoolQC', axis = 1)
test = test.join(one_hot, rsuffix = 'PoolQC')

one_hot = pd.get_dummies(train['Fence'])
train = train.drop('Fence', axis = 1)
train = train.join(one_hot, rsuffix = 'Fence')
one_hot = pd.get_dummies(test['Fence'])
test = test.drop('Fence', axis = 1)
test = test.join(one_hot, rsuffix = 'Fence')

one_hot = pd.get_dummies(train['MiscFeature'])
train = train.drop('MiscFeature', axis = 1)
train = train.join(one_hot, rsuffix = 'MiscFeature')
one_hot = pd.get_dummies(test['MiscFeature'])
test = test.drop('MiscFeature', axis = 1)
test = test.join(one_hot, rsuffix = 'MiscFeature')

one_hot = pd.get_dummies(train['SaleType'])
train = train.drop('SaleType', axis = 1)
train = train.join(one_hot, rsuffix = 'SaleType')
one_hot = pd.get_dummies(test['SaleType'])
test = test.drop('SaleType', axis = 1)
test = test.join(one_hot, rsuffix = 'SaleType')

one_hot = pd.get_dummies(train['SaleCondition'])
train = train.drop('SaleCondition', axis = 1)
train = train.join(one_hot, rsuffix = 'SaleCondition')
one_hot = pd.get_dummies(test['SaleCondition'])
test = test.drop('SaleCondition', axis = 1)
test = test.join(one_hot, rsuffix = 'SaleCondition')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
trainCorr = train.corr(method = 'pearson')
trainCorr.to_csv('/content/drive/My Drive/trainCorr.csv')

# %% [markdown]
# ![awdawdawaaaaaaa.PNG](data:image/png;base64,...)

# %% [markdown]
# OverallQual, GrLiveArea, ExterQual, GarageCars, TotalBsmtSF, 1stFlrSF, FullBath, TotRmsAbvGrd, YearBuilt

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Apr 15 11:02:52 2022

@author: Harikesh
"""

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import sklearn as sk
import sklearn.model_selection
import sklearn.linear_model
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


######################3 Data pre-processing#####################
#import the data
train= pd.read_csv('/content/drive/MyDrive/Datamining/train.csv')
# Only for the competition on kaggle the following import not for our project the test set does not contain sale price
#test = pd.read_csv('/Users/Harikesh/Desktop/CourseWork/CS2756/house-prices-advanced-regression-techniques/test.csv')

# Drop a feture if it has less than 200 useable instances
for feature in train.columns:
    if train[feature].count() <200:
        print("Dropped Feature is ",feature)
        train=train.drop(feature,axis=1)

# ONE HOT ENCODING        
#List of features to one hot encode 
attr_one_hot=['Foundation','Condition2','Exterior2nd','MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','BldgType','RoofStyle','RoofMatl','Exterior1st','Heating','CentralAir','Electrical','Functional','FireplaceQu','GarageType','GarageFinish','GarageCond','PavedDrive','Fence','SaleType','SaleCondition','MasVnrType','BsmtExposure','BsmtFinType1','GarageQual','BsmtFinType2','HouseStyle']
ohe=sklearn.preprocessing.OneHotEncoder(sparse=False) 
ohe.fit(train[attr_one_hot])
categorical_Ohe=ohe.transform(train[attr_one_hot])
categorical_Ohe=pd.DataFrame(categorical_Ohe,columns=ohe.get_feature_names())
# visualize it 
#categorical_Ohe.to_csv("/Users/Harikesh/Desktop/CourseWork/CS2756/house-prices-advanced-regression-techniques/categorical_ohe.csv")

# SCALE MAPPING
attr_scale_mapped=['ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual']
scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0,'NaN':0}
for feature in attr_scale_mapped:
    train[feature] =train[feature].replace(scale_mapper)
   
#Combine the two 
train=train.drop(attr_one_hot,axis=1)
train=train.join(categorical_Ohe)
# Visualize the table
#train.to_csv("/Users/Harikesh/Desktop/CourseWork/CS2756/house-prices-advanced-regression-techniques/step1.csv")



# Methods to do feature selection
# using corr to compare different features 
trainCorr = train.corr(method = 'pearson')
# Calculate max absolute values for corr 
corr_array = abs(trainCorr['SalePrice'])
attr_highest_corr=pd.Index.sort_values(corr_array)
#Get top 20 names of the highest corr values 
top_attr=[]
for i in range(-2,-22,-1):
    top_attr.append(attr_highest_corr.index.values.tolist()[i])
# remove features with high correlation >0.8 with each other
for feature in top_attr:
    for other_feature in top_attr:
        if feature==other_feature: continue # same feature will be 1
        if abs(trainCorr[feature].loc[other_feature])>0.8 :
            top_attr.remove(other_feature)
# top attr now has 18 names 


# selecting out the fetaures in the dataset and
# Making subsets for pre recession and post recession data 

#Now we can drop other NA like in Date year, etc,but include Sale price 
top_attr.append('YrSold')
top_attr.append('SalePrice')
 # needed for subsetting
train=train[top_attr]

train.dropna(axis=0,inplace=True,)
#train.to_csv("/content/drive/MyDrive/Datamining/train.csv/step3.csv")


# For now pending this 
# pre_X = train[train['YrSold'] < 2008][top_attr]
# pre_Y= train[train['YrSold'] < 2008]['SalePrice']

# post_X = train.loc[train['YrSold'] >= 2008][top_attr]
# post_Y= train.loc[train['YrSold'] >= 2008]['SalePrice']

# Train / Test split assumin 15 percent for testing


train_,test_=sklearn.model_selection.train_test_split(train, test_size=0.15)

X_train=train_.iloc[0:1202,0:16]
Y_train=train_.iloc[0:1202,17:17]

X_test=test_.iloc[0:213,0:16]
Y_test=test_.iloc[0:213,17:17]


split_data=sklearn.model_selection.train_test_split(train, test_size=0.15)
split_data
def performace(m,X_train=X_train,Y_train=Y_train,X_test=X_test,Y_test=Y_test,model_name="Default /n"):
    # Test Accuracy
    print(model_name)
    print("Train score: {:.2f}".format(m.score(X_train, Y_train)))
    print("Test score: {:.2f}".format(m.score(X_test, Y_test)))


# 1 simple linear regression
train_,test_=sklearn.model_selection.train_test_split(train, test_size=0.15)

X_train=train_.iloc[0:1202,0:16]
Y_train=train_.iloc[0:1202,16:17]

X_test=test_.iloc[0:213,0:16]
Y_test=test_.iloc[0:213,16:17]

def performace(m,X_train=X_train,Y_train=Y_train,X_test=X_test,Y_test=Y_test,model_name="Default /n"):
    # Test Accuracy
    print(model_name)
    print("Train score: {:.2f}".format(m.score(X_train, Y_train)))
    print("Test score: {:.2f}".format(m.score(X_test, Y_test)))


# 1 simple linear regression
linreg= sklearn.linear_model.LinearRegression()
linreg=linreg.fit(X_train,Y_train)
linreg.score(X_train,Y_train)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dropped Feature is  Alley
# Dropped Feature is  PoolQC
# Dropped Feature is  MiscFeature
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 0.7831515493032584

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y, ypred)

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

train = pd.read_csv('/content/drive/MyDrive/Datamining/train.csv')

train = train.drop(['PoolQC', 'Alley'], axis = 1)
train = train.dropna()

dummies = pd.get_dummies(train[['Foundation','Condition2', 'Exterior2nd','MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','BldgType','RoofStyle','RoofMatl','Exterior1st','Heating','CentralAir','Electrical','Functional','FireplaceQu','GarageType','GarageFinish','GarageCond','PavedDrive','Fence','SaleType','SaleCondition','MasVnrType','BsmtExposure','BsmtFinType1','GarageQual','BsmtFinType2','HouseStyle']])
y = train['SalePrice']

#print(dummies.head())

# SCALE MAPPING
attr_scale_mapped=['ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual']
scale_mapper = {'Ex':5, 'Gd':4, 'TA':3, 'Fa':2, 'Po':1, 'NA':0,'NaN':0}
for feature in attr_scale_mapped:
    train[feature] = train[feature].replace(scale_mapper)

x_numerical = train.drop(['SalePrice', 'MiscFeature','Foundation','Condition2','Exterior2nd','MSSubClass','MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','BldgType','RoofStyle','RoofMatl','Exterior1st','Heating','CentralAir','Electrical','Functional','FireplaceQu','GarageType','GarageFinish','GarageCond','PavedDrive','Fence','SaleType','SaleCondition','MasVnrType','BsmtExposure','BsmtFinType1','GarageQual','BsmtFinType2','HouseStyle'], axis = 1).astype('float64') 

x_numerical.to_csv('/content/drive/My Drive/xnum.csv')

list_numerical = x_numerical.columns
x = pd.concat([x_numerical, dummies], axis = 1)
#x.info()

#y = sk.preprocessing.minmax_scale(train['SalePrice'])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 10)

scaler = StandardScaler().fit(x_train[list_numerical])

scalerY = MinMaxScaler()
#y_train['SalePrice'] = scaler.fit_transform(y_train['SalePrice'].values.reshape(0,1))

x_train[list_numerical] = scaler.transform(x_train[list_numerical])
x_test[list_numerical] = scaler.transform(x_test[list_numerical])

#y_train['SalePrice'] = scalerY.transform(y_train['SalePrice'])
#y_test['SalePrice'] = scalerY.transform(y_test['SalePrice'])

reg = Lasso(alpha = 1)
reg.fit(x_train, y_train)

print('R squared training set', round(reg.score(x_train, y_train)*100, 2))
print('R squared test set', round(reg.score(x_test, y_test)*100, 2))

pred_train = reg.predict(x_train)
mse_train = mean_squared_error(y_train, pred_train)
print('MSE training set', round(mse_train, 2))

pred = reg.predict(x_test)
mse_test =mean_squared_error(y_test, pred)
print('MSE test set', round(mse_test, 2))

model = LassoCV(cv=5, random_state=0, max_iter=10000)
model.fit(x_train, y_train)

print(model.alpha_)

lasso_best = Lasso(alpha = model.alpha_)
lasso_best.fit(x_train, y_train)

print('R squared training set', round(lasso_best.score(x_train, y_train)*100, 2))
print('R squared test set', round(lasso_best.score(x_test, y_test)*100, 2))
#print(mean_squared_error(y_test, lasso_best.predict(x_test)))

pred_train = lasso_best.predict(x_train)
mse_train = mean_squared_error(y_train, pred_train)
print('MSE training set', round(mse_train, 2))

pred = lasso_best.predict(x_test)
mse_test =mean_squared_error(y_test, pred)
print('MSE test set', round(mse_test, 2))

print(list(zip(lasso_best.coef_, x)))


plt.semilogx(model.alphas_, model.mse_path_, ":")
plt.plot(
    model.alphas_ ,
    model.mse_path_.mean(axis=-1),
    "k",
    label="Average across the folds",
    linewidth=2,
)
plt.axvline(
    model.alpha_, linestyle="--", color="k", label="alpha: CV estimate"
)

plt.legend()
plt.xlabel("alphas")
plt.ylabel("Mean square error")
plt.title("Mean square error on each fold")
plt.axis("tight")

ymin, ymax = 50000, 250000
plt.ylim(ymin, ymax);
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# R squared training set 100.0
# R squared test set -60.31
# MSE training set 8.93
# MSE test set 1952655917.71
# 1212.041319728106
# R squared training set 99.95
# R squared test set 64.12
# MSE training set 1801225.28
# MSE test set 437022872.88
# ...
